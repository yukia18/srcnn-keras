# %%
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
dirname = './test'
dir_list = os.listdir(dirname)
images = [cv2.cvtColor(cv2.imread(os.path.join(dirname,img)),cv2.COLOR_BGR2GRAY) for img in dir_list]
images = [img[0:img.shape[0]-np.mod(img.shape[0],3),0:img.shape[1]-np.mod(img.shape[1],3)] for img in images]

# %%
images = np.array(images)

# %%
images.shape
# Out:
# (1, 255, 255)

# %%
dirname = './result'
answer_image = cv2.imread(os.path.join(dirname,'answer.bmp'))
predict_image = cv2.imread(os.path.join(dirname,'predicted.bmp'))

# %%
'image{:02}'.format(10)+'_answer'
# Out:
# 'image10_answer'

# %%
answer_image = answer_image[:,:,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-808faa66d53b> in <module>()
# ----> 1 answer_image = answer_image[:,:,0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
predict_image = predict_image[:,:,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f61927b48cb0> in <module>()
# ----> 1 predict_image = predict_image[:,:,0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.imshow(answer_image)
plt.gray()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3b2c75e99102> in <module>()
# ----> 1 plt.imshow(answer_image)
#       2 plt.gray()
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
plt.imshow(predict_image)
plt.gray()

# %%
answer_image = answer_image[6:249,6:249]

# %%
plt.imshow(answer_image)
plt.gray()

# %%
psnr(answer_image,predict_image)
# Out:
# 32.0455910975845

# %%
ssim(answer_image,predict_image)
# Out:
# 0.9646289346382145
